# %% [markdown]
# ---
#
# # ✅ Introducción a la criptografía cuántica — Respuestas
#
# ### Solucionario del protocolo BB84
#
# **TECNOLÓGICO NACIONAL DE MÉXICO · CENIDET**
# Agosto 2026
#
# ---

# %%
# %pip install -q "qiskit[visualization]" qiskit-aer pandas

from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
from IPython.display import display

print("✅ Entorno preparado")

# %% [markdown]
# ## Ejercicio 1 — Respuesta
#
# El bit 1 en la base Z se prepara aplicando X.

# %%
ejercicio_1 = QuantumCircuit(1)
ejercicio_1.x(0)

estado_e1 = Statevector.from_instruction(ejercicio_1)
display(ejercicio_1.draw('mpl'))
display(estado_e1.draw('latex'))
display(plot_bloch_multivector(estado_e1))

# %% [markdown]
# ## Ejercicio 2 — Respuesta
#
# El bit 0 en la base X es `|+⟩` y se prepara aplicando H.

# %%
ejercicio_2 = QuantumCircuit(1)
ejercicio_2.h(0)

estado_e2 = Statevector.from_instruction(ejercicio_2)
display(ejercicio_2.draw('mpl'))
display(estado_e2.draw('latex'))
display(plot_bloch_multivector(estado_e2))

# %% [markdown]
# ## Ejercicio 3 — Respuesta
#
# Las bases coinciden en las posiciones 1, 3, 5 y 6.
#
# Los bits de Alice en esas posiciones son:
#
# ```text
# 1 1 0 0
# ```
#
# Por tanto, la clave filtrada es `1100`.

# %% [markdown]
# ## Ejercicio 4 — Respuesta
#
# 1. Eve no conoce las bases de Alice cuando intercepta los qubits.
# 2. Si elige una base equivocada, obtiene un resultado aleatorio y puede modificar el estado que recibe Bob.
# 3. Alice y Bob calculan el QBER, que representa la proporción de errores en los bits comparados.

# %% [markdown]
# ---
#
# # 🎯 Resumen
#
# La seguridad de BB84 aprovecha que una medición incorrecta deja señales estadísticas. Alice y Bob no utilizan una clave si la tasa de error observada es demasiado grande.
